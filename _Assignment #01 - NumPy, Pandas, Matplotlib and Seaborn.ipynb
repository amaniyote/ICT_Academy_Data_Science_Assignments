# %%
# 1.Read the dataset to python environment.
import pandas as pd

dataframe = pd.read_excel('iris.xls')
 
print(dataframe)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 2.Display the columns in the dataset.
dataframe.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
# 3.Calculate the mean of each column of the dataset.
mean1 = dataframe['SL'].mean()
print('SL:mean =',mean1)
mean2 = dataframe['SW'].mean()
print('SW:mean =',mean2)
mean3 = dataframe['PL'].mean()
print('PL:mean =',mean3)
mean4 = dataframe['PW'].mean()
print('PW:mean =',mean4)
# Out:
# SL:mean = 5.843333333333334
# SW:mean = 3.0540000000000003
# PL:mean = 3.758666666666666
# PW:mean = 1.1986666666666668

# %%
# 4.Check for the null values present in the dataset.
dataframe.info()
dataframe.isnull().head(150)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# ...

# %% [markdown]
# # 5.Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.
#
# # Visualization 1 - Classification vs Max values
# ![Classification%20vs%20Max%20Value.png](attachment:Classification%20vs%20Max%20Value.png)

# %% [markdown]
# # Visualization 2 - Classification vs Median of Sepal Length & Width
# ![Classification%20vs%20Median%20of%20Sepal%20Length%20&%20Width.png](attachment:Classification%20vs%20Median%20of%20Sepal%20Length%20&%20Width.png)

# %% [markdown]
# # Visualization 3 - Classification,Petal & Sepal length vs Petal & Sepal Width
# ![Classification,Petal%20&%20Sepal%20length%20vs%20Petal%20&%20Sepal%20Width.png](attachment:Classification,Petal%20&%20Sepal%20length%20vs%20Petal%20&%20Sepal%20Width.png)
