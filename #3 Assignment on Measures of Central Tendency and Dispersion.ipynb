# %%
# 1.Read the dataset
import pandas as pd

dataset = pd.read_csv(r"C:\Users\amani\OneDrive\Desktop\KKEM-ICT-DSA\StudentsPerformance.csv")  
dataset
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# 1. Find out how many males and females participated in the test.

dataset.groupby(["gender"]).count()
# Out:
#         race/ethnicity  parental level of education  lunch  \
# gender
# female             518                          518    518
# male               482                          482    482
#
#         test preparation course  math score  reading score  writing score
# gender
# female                      518         518            518            518
# male                        482         482            482            482

# %%
#Conclusion: 518 females participated in test 
        #482 males participated in test

# %%
#2 What do you think about the students parental level of education?
edulvl = dataset.groupby(["parental level of education"]).describe()
edulvl
# Out:
#                             math score                                     \
#                                  count       mean        std   min    25%
# parental level of education
# associate's degree               222.0  67.977477  15.108190  26.0  57.00
# bachelor's degree                118.0  69.288136  15.164117  29.0  61.00
# high school                      196.0  61.821429  15.160466   8.0  53.75
# master's degree                   59.0  70.254237  14.843544  40.0  57.00
# some college                     226.0  67.128319  14.871790  11.0  59.00
# some high school                 179.0  63.134078  16.602894   0.0  53.00
#
#                                                reading score             ...  \
#                               50%   75%    max         count       mean  ...
# parental level of education                                              ...
# associate's degree           67.0  80.0  100.0         222.0  71.018018  ...
# ...

# %%
#Conclusion:By analysing students perfomance in math score,reading score & writing score its clear that students having master's degree as parental level of education are perfoming well.

# %%
#3 Who scores the most on average for math, reading and writing based on
#3.1 Gender
dataset1 = dataset[['gender', 'math score', 'reading score', 'writing score']].groupby('gender').mean()
dataset1
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
#Conclusion: Female students have higher average reading and writing while male students have higher average in maths.

# %%
#3.2 Test preparation course
dataset2= dataset[['test preparation course', 'math score', 'reading score', 'writing score']].groupby('test preparation course').mean()
dataset2
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
#Conclusion: Students who did test preparation course have higher average score across all categories

# %%
#4 What do you think about the scoring variation for math, reading and writing based on
#4.1 gender
gen= dataset[['gender', 'math score', 'reading score', 'writing score']].groupby('gender').std()
gen
# Out:
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %%
#Conclusion: Male students have less variations across each of the scores

# %%
#4.2 Test preparation course
test= dataset[['test preparation course', 'math score', 'reading score', 'writing score']].groupby('test preparation course').std()
test
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %%
#Conclusion: The variation between those who have completed test preparation course and none are more or less having same.

# %%
#5 The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this.
dataset.nlargest(250, ['math score'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 428  female        group D                some college  free/reduced
# 429  female        group E            some high school      standard
# 849    male        group A           bachelor's degree      standard
# 850    male        group C          associate's degree  free/reduced
# 851    male        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Conclusion: List of top 250 students who are eligible for bonus points.
