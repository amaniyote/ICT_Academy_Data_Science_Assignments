# %%
import pandas as pd
import  numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.Load the dataset into python environment

# %%
pd.read_csv(r'C:\Users\amani\OneDrive\Desktop\KKEM-ICT-DSA\titanic_dataset.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = pd.read_csv(r'C:\Users\amani\OneDrive\Desktop\KKEM-ICT-DSA\titanic_dataset.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 2. Make ‘PassengerId’ as the index column

# %%
data = pd.read_csv(r'C:\Users\amani\OneDrive\Desktop\KKEM-ICT-DSA\titanic_dataset.csv',index_col='PassengerId')

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# # 3.Check the basic details of the dataset

# %%
data.shape
# Out:
# (891, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # 4. Fill in all the missing values present in all the columns in the dataset

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
freqgraph = data.select_dtypes(include=['float'])
freqgraph.hist(figsize=(15,10))
plt.show()

# %%
data['Age'] = data['Age'].fillna(data['Age'].median())

# %%
data['Age'].isna().sum()
# Out:
# 0

# %%
data['Cabin'] = data['Cabin'].fillna('NOTKNOWN')

# %%
data['Cabin'].isna().sum()
# Out:
# 0

# %%
data['Embarked'] = data['Embarked'].fillna('NOTKNOWN')

# %%
data['Embarked'].isna().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %% [markdown]
# # 5. Check and handle outliers in at least 3 columns in the dataset

# %%
plt.boxplot(data['Age'])
plt.title('BoxPlot of Age')
# Out:
# Text(0.5, 1.0, 'BoxPlot of Age')

# %%
plt.boxplot(data['Fare'])
plt.title('BoxPlot of Fare')
# Out:
# Text(0.5, 1.0, 'BoxPlot of Fare')

# %%
plt.boxplot(data['SibSp'])
plt.title('BoxPlot of SibSp')
# Out:
# Text(0.5, 1.0, 'BoxPlot of SibSp')

# %%
Q1 = np.percentile(data['Age'], 25, interpolation='midpoint')
print(Q1)
Q2 = np.percentile(data['Age'], 50, interpolation='midpoint')
print(Q2)
Q3 = np.percentile(data['Age'], 75, interpolation='midpoint')
print(Q3)
# Out:
# 22.0
# 28.0
# 35.0

# %%
data['Age'].median()
# Out:
# 28.0

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 13.0

# %%
lower_lim = Q1-1.5*IQR
print(lower_lim)
upper_lim = Q3+1.5*IQR
print(upper_lim)
# Out:
# 2.5
# 54.5

# %%
outlier = []
for x in data['Age']:
    if (x>upper_lim) or (x<lower_lim):
        outlier.append(x)

# %%
outlier
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
index = data['Age'] > upper_lim

# %%
data.loc[index].index
# Out:
# Int64Index([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
#             269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
#             556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
#             830, 852, 880],
#            dtype='int64', name='PassengerId')

# %%
data.drop([12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
            269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
            556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
            830, 852, 880], inplace = True)

# %%
data.head(20)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 13                  0       3
# 14                  0       3
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# ...

# %%
Q1 = np.percentile(data['Fare'], 25, interpolation='midpoint')
print(Q1)
Q2 = np.percentile(data['Fare'], 50, interpolation='midpoint')
print(Q2)
Q3 = np.percentile(data['Fare'], 75, interpolation='midpoint')
print(Q3)
# Out:
# 7.8958
# 14.25415
# 30.5

# %%
data['Fare'].median()
# Out:
# 14.25415

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 22.6042

# %%
lower_lim = Q1-1.5*IQR
print(lower_lim)
upper_lim = Q3+1.5*IQR
print(upper_lim)
# Out:
# -26.0105
# 64.4063

# %%
outlier = []
for x in data['Fare']:
    if (x>upper_lim) or (x<lower_lim):
        outlier.append(x)
outlier
# Out:
# [71.2833,
#  263.0,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  263.0,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  69.55,
#  69.55,
#  69.55,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  135.6333,
#  78.85,
#  91.0792,
#  151.55,
#  247.5208,
#  151.55,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  69.55,
#  135.6333,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  263.0,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  93.5,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  78.2667,
#  153.4625,
#  65.0,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
#  211.3375,
#  110.8833,
#  227.525,
#  151.55,
#  227.525,
#  211.3375,
# ...

# %%
index = data['Fare'] > upper_lim

# %%
data.loc[index].index
# Out:
# Int64Index([  2,  28,  32,  35,  53,  62,  63,  89, 103, 119,
#             ...
#             780, 790, 793, 803, 821, 836, 847, 850, 857, 864],
#            dtype='int64', name='PassengerId', length=107)

# %%
data.drop([2,  28,  32,  35,  53,  62,  63,  89, 103, 119], inplace = True)

# %%
data.head(20)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 13                  0       3
# 14                  0       3
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# ...

# %%
Q1 = np.percentile(data['SibSp'], 25, interpolation='midpoint')
print(Q1)
Q2 = np.percentile(data['SibSp'], 50, interpolation='midpoint')
print(Q2)
Q3 = np.percentile(data['SibSp'], 75, interpolation='midpoint')
print(Q3)
# Out:
# 0.0
# 0.0
# 1.0

# %%
data['SibSp'].median()
# Out:
# 0.0

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 1.0

# %%
lower_lim = Q1-1.5*IQR
print(lower_lim)
upper_lim = Q3+1.5*IQR
print(upper_lim)
# Out:
# -1.5
# 2.5

# %%
outlier = []
for x in data['SibSp']:
    if (x>upper_lim) or (x<lower_lim):
        outlier.append(x)

# %%
outlier
# Out:
# [3,
#  4,
#  3,
#  4,
#  5,
#  3,
#  4,
#  5,
#  3,
#  4,
#  8,
#  4,
#  4,
#  3,
#  8,
#  4,
#  8,
#  3,
#  4,
#  4,
#  4,
#  4,
#  8,
#  3,
#  3,
#  5,
#  3,
#  5,
#  3,
#  4,
#  4,
#  3,
#  3,
#  5,
#  4,
#  3,
#  4,
#  8,
#  4,
#  3,
#  4,
#  8,
#  4,
#  8]

# %%
index = data['SibSp'] > upper_lim

# %%
data.loc[index].index
# Out:
# Int64Index([  8,  17,  25,  51,  60,  64,  69,  72,  86, 120, 160, 165, 172,
#             177, 181, 183, 202, 230, 234, 262, 267, 279, 325, 342, 375, 387,
#             410, 481, 486, 542, 543, 635, 643, 684, 687, 727, 788, 793, 814,
#             820, 825, 847, 851, 864],
#            dtype='int64', name='PassengerId')

# %%
data.drop([8,  17,  25,  51,  60,  64,  69,  72,  86, 120, 160, 165, 172,
            177, 181, 183, 202, 230, 234, 262, 267, 279, 325, 342, 375, 387,
            410, 481, 486, 542, 543, 635, 643, 684, 687, 727, 788, 793, 814,
            820, 825, 847, 851, 864], inplace = True)

# %%
data.head(20)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 13                  0       3
# 14                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 26                  1       3
# 27                  0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# ...

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %% [markdown]
# # 5.Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
data.shape
# Out:
# (790, 11)

# %%
data1 = pd.get_dummies(data)

# %%
data1.shape
# Out:
# (790, 1566)

# %%
data['Survived'].nunique()
# Out:
# 2

# %%
data2 = data.drop('Survived', axis=1)

# %%
data2.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 1                 3                       Braund, Mr. Owen Harris    male
# 3                 3                        Heikkinen, Miss. Laina  female
# 4                 1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                 3                      Allen, Mr. William Henry    male
# 6                 3                              Moran, Mr. James    male
#
#               Age  SibSp  Parch            Ticket     Fare        Cabin  \
# PassengerId
# 1            22.0      1      0         A/5 21171   7.2500  C23 C25 C27
# 3            26.0      0      0  STON/O2. 3101282   7.9250     NOTKNOWN
# 4            35.0      1      0            113803  53.1000         C123
# 5            35.0      0      0            373450   8.0500     NOTKNOWN
# 6            28.0      0      0            330877   8.4583     NOTKNOWN
#
#             Embarked
# PassengerId
# 1                  S
# ...

# %%
data2 = pd.get_dummies(data2)

# %%
data2.shape
# Out:
# (790, 1565)

# %%
data2.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Name_Abbing, Mr. Anthony',
#        'Name_Abbott, Mr. Rossmore Edward',
#        'Name_Abbott, Mrs. Stanton (Rosa Hunt)', 'Name_Abelson, Mr. Samuel',
#        'Name_Abelson, Mrs. Samuel (Hannah Wizosky)',
#        ...
#        'Cabin_F2', 'Cabin_F33', 'Cabin_F38', 'Cabin_F4', 'Cabin_G6',
#        'Cabin_NOTKNOWN', 'Cabin_T', 'Embarked_C', 'Embarked_Q', 'Embarked_S'],
#       dtype='object', length=1565)

# %%
from sklearn import preprocessing

# %%
lbl_enc = preprocessing.LabelEncoder()

# %%
data['Survived'] = lbl_enc.fit_transform(data['Survived'])

# %%
data.head()
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250
# 4            female  35.0      1      0            113803  53.1000
# 5              male  35.0      0      0            373450   8.0500
# 6              male  28.0      0      0            330877   8.4583
#
#                    Cabin Embarked
# PassengerId
# ...

# %%
X = data.drop('Survived', axis=1)
y= data['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
model = lin_reg.fit(X_train,y_train)
predictions = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [111], in <cell line: 2>()
#       1 lin_reg = LinearRegression()
# ----> 2 model = lin_reg.fit(X_train,y_train)
#       3 predictions = model.predict(X_test)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
data3 = data.drop(['Name','Sex','Ticket','Cabin','Embarked'], axis = 1)

# %%
X = data3.drop('Survived', axis = 1)
y =data3['Survived']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size = 0.2)

# %%
lin_reg = LinearRegression()
model = lin_reg.fit(X_train,y_train)
predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
print('The mean squared error value is: ', mean_squared_error(y_test, predictions))
print('The r squared value is: ', r2_score(y_test, predictions))
# Out:
# The mean squared error value is:  0.2008369137186292
# The r squared value is:  0.1355702217117486

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  790.000000  790.000000  790.000000  790.000000  790.000000  790.000000
# mean     0.402532    2.329114   28.521734    0.321519    0.318987   29.679029
# std      0.490719    0.819928   10.513159    0.537956    0.769849   48.229310
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   23.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   13.000000
# 75%      1.000000    3.000000   34.000000    1.000000    0.000000   27.720800
# max      1.000000    3.000000   54.000000    2.000000    6.000000  512.329200

# %%
X1 = data3.drop('Survived',axis = 1)

# %%
X1.head()
# Out:
#              Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                 3  22.0      1      0   7.2500
# 3                 3  26.0      0      0   7.9250
# 4                 1  35.0      1      0  53.1000
# 5                 3  35.0      0      0   8.0500
# 6                 3  28.0      0      0   8.4583

# %%
X1
# Out:
# array([[1.        , 0.40276222, 0.5       , 0.        , 0.01415106],
#        [1.        , 0.47741695, 0.        , 0.        , 0.01546857],
#        [0.        , 0.64539007, 0.5       , 0.        , 0.1036443 ],
#        ...,
#        [1.        , 0.51474431, 0.5       , 0.33333333, 0.04577135],
#        [0.        , 0.47741695, 0.        , 0.        , 0.0585561 ],
#        [1.        , 0.58939903, 0.        , 0.        , 0.01512699]])

# %%
min_max_scale = preprocessing.MinMaxScaler(feature_range=(0,1))

# %%
X1 = min_max_scale.fit_transform(X1)

# %%
X1 = pd.DataFrame(X1, columns =['Pclass','Age','SibSp','Parch','Fare'])

# %%
X1.head()
# Out:
#    Pclass       Age  SibSp  Parch      Fare
# 0     1.0  0.402762    0.5    0.0  0.014151
# 1     1.0  0.477417    0.0    0.0  0.015469
# 2     0.0  0.645390    0.5    0.0  0.103644
# 3     1.0  0.645390    0.0    0.0  0.015713
# 4     1.0  0.514744    0.0    0.0  0.016510

# %%
X1.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  790.000000  790.000000  790.000000  790.000000  790.000000
# mean     0.664557    0.524482    0.160759    0.053165    0.057930
# std      0.409964    0.196214    0.268978    0.128308    0.094137
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.421426    0.000000    0.000000    0.015412
# 50%      1.000000    0.514744    0.000000    0.000000    0.025374
# 75%      1.000000    0.626726    0.500000    0.000000    0.054107
# max      1.000000    1.000000    1.000000    1.000000    1.000000

# %%
data3.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  22.0      1      0   7.2500
# 3                   1       3  26.0      0      0   7.9250
# 4                   1       1  35.0      1      0  53.1000
# 5                   0       3  35.0      0      0   8.0500
# 6                   0       3  28.0      0      0   8.4583

# %%
data3.drop(['Pclass','Age','SibSp','Parch','Fare'],axis = 1,inplace=True)

# %%
data3.head()
# Out:
#              Survived
# PassengerId
# 1                   0
# 3                   1
# 4                   1
# 5                   0
# 6                   0

# %%
data3 = pd.concat([data3,X1],axis = 1)

# %%
data3.head()
# Out:
#    Survived  Pclass       Age  SibSp     Parch      Fare
# 1       0.0     1.0  0.477417    0.0  0.000000  0.015469
# 3       1.0     1.0  0.645390    0.0  0.000000  0.015713
# 4       1.0     1.0  0.514744    0.0  0.000000  0.016510
# 5       0.0     0.0  1.000000    0.0  0.000000  0.101229
# 6       0.0     1.0  0.496081    0.0  0.333333  0.021731
